# %% [markdown]
# ### Exercise 1.
# Calculate sum and product of two integer numbers:

# %%
number1 = 5

number2 = 7

#YOUR CODE HERE
sum = number1 + number2
product = number1 * number2
print(f"Sum of 5 and 7 is {sum}; product of 5 and 7 is {product}")
# Out:
# Sum of 5 and 7 is 12; product of 5 and 7 is 35

# %% [markdown]
# Expected result: "Sum of 5 and 7 is 12; product of 5 and 7 is 35" printed

# %% [markdown]
# ### Exercise 2.
# Repeat the string n times (Hint: check the ** operator for strings)

# %%
times = 5
s = "Hey! "


# YOUR CODE HERE

# Expected result: "Hey! Hey! Hey! Hey! Hey! " printed
print(s*times)
# Out:
# Hey! Hey! Hey! Hey! Hey!

# %% [markdown]
# ### Exercise 3.
# Calculate the age given the year of birth

# %%
birth_year = 1980
# YOUR CODE HERE
import datetime
x = datetime.datetime.now()
now = x.year
age = now - birth_year
print(f"Your age is {age} or if your birthday has happened then {age + 1}")
# Expected result: "Your age is 41 or 42 years"
# Out:
# Your age is 43 or if your birthday has happened then 44

# %% [markdown]
# ### Exercise 4.
# Divide two integers with a remainder

# %%
dividend = 17
divisor = 6
# YOUR CODE HERE
quotient = dividend // divisor
remainder = dividend % divisor
print(f"The quotient is {quotient} and the remainder is {remainder}")
# Expected result: "The quotient is 2 and the remainder is 5"
# Out:
# The quotient is 2 and the remainder is 5

# %% [markdown]
# ### Exercise 5.
# Print pi (math.pi) with 10 decimal places

# %%
import math
# YOUR CODE HERE
print(f"Pi is {math.pi:.10f}")
# Expected result: "Pi is 3.1415926536"
# Out:
# Pi is 3.1415926536

# %% [markdown]
# ### Exercise 6.
# Introduce variables with current exchange rates and convert 10 euro to pounds (GBP) and dollars ($)

# %%
value = 10 # euro
# YOUR CODE HERE
eur_to_usd = 1.06
eur_to_gdp = .86

print(f"{value} euro is {value*eur_to_gdp:.2f} pounds (GBP) or {value*eur_to_usd:.2f} dollars (USD)")
# Expected result (approx.): "10 euro is 8.68 pounds (GBP) or 10.02 dollars (USD)
# Out:
# 10 euro is 8.60 pounds (GBP) or 10.60 dollars (USD)

# %% [markdown]
# ### Exercise 7.
# Print a string by one symbol in line

# %%
name = "Gonzalo" # repalce with your name
# YOUR CODE HERE
for letter in name:
  print(letter)
# Expected result:
# D
# m
# i
# t
# r
# y
# Out:
# G
# o
# n
# z
# a
# l
# o

# %% [markdown]
# ### Exercise 8.
# Calculate the age given the date of birth

# %%
birth_date = "1980-Jul-6"
# YOUR CODE HERE
from datetime import datetime
bday = datetime.strptime(birth_date, "%Y-%b-%d")
todays_date = datetime.now()
age = (todays_date-bday).days // 365
print(f"Your age is {age} years")
# probably a better way to set this up
# Expected result: "Your age is 42 years"
# Out:
# Your age is 43 years
